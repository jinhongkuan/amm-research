# %%
import Pkg
Pkg.add("Plots")
Pkg.add("MultivariateStats")
Pkg.add("RDatasets")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.9/Project.toml`
#   No Changes to `~/.julia/environments/v1.9/Manifest.toml`
#    Resolving package versions...
#    Installed Arpack_jll ──────── v3.5.1+1
#    Installed Arpack ──────────── v0.5.4
#    Installed MultivariateStats ─ v0.10.2
#     Updating `~/.julia/environments/v1.9/Project.toml`
#   [6f286f6a] + MultivariateStats v0.10.2
#     Updating `~/.julia/environments/v1.9/Manifest.toml`
#   [7d9fca2a] + Arpack v0.5.4
#   [6f286f6a] + MultivariateStats v0.10.2
# ⌅ [68821587] + Arpack_jll v3.5.1+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ Arpack_jll
#   ✓ Arpack
#   ✓ MultivariateStats
#   3 dependencies successfully precompiled in 2 seconds. 182 already precompiled.
# ...

# %%
0.709339411776955386 / (BigInt(81218362623392879345829310187)^2 / BigInt(2)^192 * 0.675334661353945723)
# Out:
# 0.9995068113065604742018094636993407454108237436192394737968700644542503848952226

# %%
using Plots
using MultivariateStats
using RDatasets

cars = dataset("datasets", "cars")

a = llsq(cars[!,:Speed], cars[!,:Dist])

scatter(cars[!,:Speed], cars[!,:Dist], label="Data")
plot!(cars[!,:Speed], a[2] .+ a[1] .* cars[!,:Speed], label="Fit")
